# %%
import gzip, json
with gzip.open('/data/NPMvulnerabilities/NPMPackages.json.gz', 'rb') as f:
   fc = f.read().decode("utf-8")
from json import JSONDecoder, JSONDecodeError
import re

NOT_WHITESPACE = re.compile(r'[^\s]')

def decode_stacked(document, pos=0, decoder=JSONDecoder()):
   while True:
       match = NOT_WHITESPACE.search(document, pos)
       if not match:
           return
       pos = match.start()

       try:
           obj, pos = decoder.raw_decode(document, pos)
       except JSONDecodeError:
           # do something sensible if there's some error
           print("DECODE_STACKED() FAILED")
           pass
       yield obj

# %%
#pkgs = ['htmlnano', 'object.map', 'babylon-walk', 'wix-style-react', 'threads', 'minimist-options', 'lead', '@babel/polyfill', '@babel/helper-define-map', 'cloudscraper']
pkgs = ['ajv-keywords']
dependent = {}
for pkg in pkgs:
   dependent[pkg] = []
   for obj in decode_stacked(fc):
       ind = 0
       try: versions = list(obj['versions'].keys())
       except: continue
       try: release_dates = obj['time']
       except: continue
       info = {key: {'release_date': release_dates[key]} for key in release_dates if key not in ['created', 'modified']}
       for key in versions:
           try:
               info[key]['dependencies'] = list(obj['versions'][key]['dependencies'].keys())
               if pkg in info[key]['dependencies']: ind = 1
           except: continue
       if ind :
           dependent[pkg].append({obj['name']: info})

# %%
for k in dependent.keys():
   if k == 'ajv-keywords':
       print(k, dependent[k][:20])
       print("len = ", len(dependent[k]))
       break
# Out:
# ajv-keywords [{'jsonscript-proxy': {'0.1.0': {'dependencies': ['ajv-keywords', 'request', 'jsonscript-js', 'lodash', 'ajv'], 'release_date': '2016-06-11T21:10:29.541Z'}, '0.2.1': {'dependencies': ['jsonscript-js', 'lodash', 'ajv', 'ajv-keywords', 'request', 'express', 'minimist', 'body-parser'], 'release_date': '2016-06-19T20:02:13.556Z'}, '0.5.0': {'dependencies': ['jsonscript-js', 'lodash', 'ajv', 'ajv-keywords', 'request', 'express', 'minimist', 'body-parser'], 'release_date': '2016-07-03T18:11:48.345Z'}, '0.2.0': {'dependencies': ['jsonscript-js', 'lodash', 'ajv', 'ajv-keywords', 'request', 'express', 'minimist', 'body-parser'], 'release_date': '2016-06-12T20:28:36.532Z'}, '0.1.1': {'dependencies': ['ajv-keywords', 'request', 'jsonscript-js', 'lodash', 'ajv'], 'release_date': '2016-06-11T22:09:59.274Z'}}}, {'senasaikou-yeoman': {'1.1.0': {'dependencies': ['gulp-size', 'gulp-htmlmin', 'gulp', 'gulp-cssnano', 'babel-preset-react', 'gulp-imagemin', 'babel-core', 'babel-register', 'gulp-less', 'gulp-uglify', 'gulp-useref', 'del', 'gulp-if', 'babel-preset-es2015', 'gulp-babel', 'gulp-cache', 'gulp-load-plugins', 'wiredep', 'main-bower-files', 'gulp-autoprefixer', 'gulp-eslint', 'gulp-plumber', 'gulp-sourcemaps', 'run-sequence', 'browser-sync'], 'release_date': '2016-10-23T14:21:58.976Z'}, '1.0.1': {'dependencies': ['gulp-size', 'gulp-htmlmin', 'gulp', 'gulp-cssnano', 'gulp-imagemin', 'babel-core', 'babel-register', 'gulp-less', 'gulp-uglify', 'gulp-useref', 'del', 'gulp-if', 'babel-preset-es2015', 'gulp-babel', 'gulp-cache', 'gulp-load-plugins', 'wiredep', 'main-bower-files', 'gulp-autoprefixer', 'gulp-eslint', 'gulp-plumber', 'gulp-sourcemaps', 'run-sequence', 'browser-sync'], 'release_date': '2016-10-23T14:14:05.343Z'}, '1.2.2': {'dependencies': ['gulp-size', 'gulp-htmlmin', 'gulp', 'gulp-cssnano', 'babel-preset-react', 'gulp-imagemin', 'babel-core', 'babel-register', 'gulp-less', 'gulp-uglify', 'gulp-useref', 'del', 'gulp-if', 'babel-preset-es2015', 'gulp-babel', 'gulp-cache', 'gulp-load-plugins', 'wiredep', 'main-bower-files', 'gulp-autoprefixer', 'gulp-eslint', 'gulp-plumber', 'gulp-sourcemaps', 'run-sequence', 'browser-sync'], 'release_date': '2016-10-30T12:10:22.245Z'}, '1.1.1': {'dependencies': ['gulp-size', 'gulp-htmlmin', 'gulp', 'gulp-cssnano', 'babel-preset-react', 'gulp-imagemin', 'babel-core', 'babel-register', 'gulp-less', 'gulp-uglify', 'gulp-useref', 'del', 'gulp-if', 'babel-preset-es2015', 'gulp-babel', 'gulp-cache', 'gulp-load-plugins', 'wiredep', 'main-bower-files', 'gulp-autoprefixer', 'gulp-eslint', 'gulp-plumber', 'gulp-sourcemaps', 'run-sequence', 'browser-sync'], 'release_date': '2016-10-24T02:12:17.111Z'}, '1.0.0': {'dependencies': ['resolve-dir', 'form-data', 'is-path-cwd', 'wiredep', 'is-plain-obj', 'prr', 'isarray', 'pinkie-promise', 'string-width', 'babel-register', 'lodash.keys', 'babel-plugin-transform-es2015-unicode-regex', 'uglify-js', 'invariant', 'num2fraction', 'arrify', 'ternary-stream', 'filename-regex', 'expand-brackets', 'inherits', 'cache-swap', 'stream-throttle', 'arraybuffer.slice', 'is-natural-number', 'buffer-to-vinyl', 'ctype', 'loose-envify', 'lodash._isiterateecall', 'exec-buffer', 'babel-messages', 'babel-traverse', 'lower-case-first', 'micromatch', 'validate-npm-package-license', 'fs-extra', 'array-differ', 'normalize-package-data', 'babel-generator', 'exit-hook', 'lodash.isarguments', 'kind-of', 'camel-case', 'tar-stream', 'lodash._root', 'babel-helper-builder-react-jsx', 'requires-port', 'yargs-parser', 'parse-filepath', 'source-map-support', 'js-base64', 'arr-diff', 'is-retry-allowed', 'postcss-colormin', 'npm-run-path', 'deep-is', 'ms', 'unique-stream', 'har-validator', 'concat-map', 'query-string', 'wrappy', 'cross-spawn-async', 'deep-extend', 'duplexer2', 'is-extendable', 'currently-unhandled', 'beeper', 'expand-range', 'vinyl-assign', 'invert-kv', 'async-each', 'jsonpointer', 'browser-sync-ui', 'esutils', 'through2', 'callsites', 'esprima', 'lodash.isequal', 'make-error' ...
# len =  157
